# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from PIL import Image, ImageDraw
from meri.utils.docling_utils import vis_layout
from meri.meri import MERI
import json
from IPython.display import display, Image, Markdown

base_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.append(base_path)
# Out:
# f:\MERI-main-test\.venv\Lib\site-packages\pydantic\_internal\_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)

# %%
pdf_path = "f:\\MERI-main-test\\data\\demo_data\\user_test.pdf"

# %%
meri = MERI(pdf_path, model="gpt-4o-mini", model_temp=0.0)

# %%
meri.to_intermediate()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File f:\MERI-main-test\.venv\Lib\site-packages\docling_core\utils\file.py:69, in resolve_source_to_stream(source, headers)
#      68 try:
# ---> 69     http_url: AnyHttpUrl = TypeAdapter(AnyHttpUrl).validate_python(source)
#      71     # make all header keys lower case
#
# File f:\MERI-main-test\.venv\Lib\site-packages\pydantic\type_adapter.py:412, in TypeAdapter.validate_python(self, object, strict, from_attributes, context, experimental_allow_partial)
#     392 """Validate a Python object against the model.
#     393
#     394 Args:
#    (...)
#     410     The validated object.
#     411 """
# --> 412 return self.validator.validate_python(
#     413     object,
#     414     strict=strict,
#     415     from_attributes=from_attributes,
#     416     context=context,
#     417     allow_partial=experimental_allow_partial,
#     418 )
#
# ValidationError: 1 validation error for function-wrap[wrap_val()]
#   URL scheme should be 'http' or 'https' [type=url_scheme, input_value='f:\\/data/demo_data/user_test.pdf', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/url_scheme
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 meri.to_intermediate()
#
# File f:\MERI-main-test\meri\meri.py:42, in MERI.to_intermediate(self)
#      41 def to_intermediate(self):
# ---> 42     self.docling_result = self.converter.convert(self.pdf_path)
#      44     self.int_format = export_to_html(self.docling_result.document)
#      46     # 如果启用布局增强，智能合并分离的键值对
#
# File f:\MERI-main-test\.venv\Lib\site-packages\pydantic\_internal\_validate_call.py:38, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      36 @functools.wraps(wrapped)
#      37 def wrapper_function(*args, **kwargs):
# ---> 38     return wrapper(*args, **kwargs)
#
# File f:\MERI-main-test\.venv\Lib\site-packages\pydantic\_internal\_validate_call.py:111, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     110 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# --> 111     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     112     if self.__return_pydantic_validator__:
#     113         return self.__return_pydantic_validator__(res)
#
# File f:\MERI-main-test\.venv\Lib\site-packages\docling\document_converter.py:161, in DocumentConverter.convert(self, source, raises_on_error, max_num_pages, max_file_size)
#     146 @validate_call(config=ConfigDict(strict=True))
#     147 def convert(
#     148     self,
#    (...)
#     152     max_file_size: int = sys.maxsize,
#     153 ) -> ConversionResult:
#     155     all_res = self.convert_all(
#     156         source=[source],
#     157         raises_on_error=raises_on_error,
#     158         max_num_pages=max_num_pages,
#     159         max_file_size=max_file_size,
#     160     )
# --> 161     return next(all_res)
#
# File f:\MERI-main-test\.venv\Lib\site-packages\docling\document_converter.py:180, in DocumentConverter.convert_all(self, source, raises_on_error, max_num_pages, max_file_size)
#     175 conv_input = _DocumentConversionInput(
#     176     path_or_stream_iterator=source,
#     177     limit=limits,
#     178 )
#     179 conv_res_iter = self._convert(conv_input, raises_on_error=raises_on_error)
# --> 180 for conv_res in conv_res_iter:
#     181     if raises_on_error and conv_res.status not in {
#     182         ConversionStatus.SUCCESS,
#     183         ConversionStatus.PARTIAL_SUCCESS,
#     184     }:
#     185         raise RuntimeError(
#     186             f"Conversion failed for: {conv_res.input.file} with status: {conv_res.status}"
#     187         )
#
# File f:\MERI-main-test\.venv\Lib\site-packages\docling\document_converter.py:198, in DocumentConverter._convert(self, conv_input, raises_on_error)
#     194 assert self.format_to_options is not None
#     196 start_time = time.monotonic()
# --> 198 for input_batch in chunkify(
#     199     conv_input.docs(self.format_to_options),
#     200     settings.perf.doc_batch_size,  # pass format_options
#     201 ):
#     202     _log.info(f"Going to convert document batch...")
#     204     # parallel processing only within input_batch
#     205     # with ThreadPoolExecutor(
#     206     #    max_workers=settings.perf.doc_batch_concurrency
#     207     # ) as pool:
#     208     #   yield from pool.map(self.process_document, input_batch)
#     209     # Note: PDF backends are not thread-safe, thread pool usage was disabled.
#
# File f:\MERI-main-test\.venv\Lib\site-packages\docling\utils\utils.py:12, in chunkify(iterator, chunk_size)
#      10 if isinstance(iterator, List):
#      11     iterator = iter(iterator)
# ---> 12 for first in iterator:  # Take the first element from the iterator
#      13     yield [first] + list(islice(iterator, chunk_size - 1))
#
# File f:\MERI-main-test\.venv\Lib\site-packages\docling\datamodel\document.py:462, in _DocumentConversionInput.docs(self, format_options)
#     458 def docs(
#     459     self, format_options: Dict[InputFormat, "FormatOption"]
#     460 ) -> Iterable[InputDocument]:
#     461     for item in self.path_or_stream_iterator:
# --> 462         obj = resolve_file_source(item) if isinstance(item, str) else item
#     463         format = self._guess_format(obj)
#     464         if format not in format_options.keys():
#
# File f:\MERI-main-test\.venv\Lib\site-packages\typing_extensions.py:2853, in deprecated.__call__.<locals>.wrapper(*args, **kwargs)
#    2850 @functools.wraps(arg)
#    2851 def wrapper(*args, **kwargs):
#    2852     warnings.warn(msg, category=category, stacklevel=stacklevel + 1)
# -> 2853     return arg(*args, **kwargs)
#
# File f:\MERI-main-test\.venv\Lib\site-packages\docling_core\utils\file.py:168, in resolve_file_source(source, headers)
#     148 @deprecated("Use `resolve_source_to_path()` or `resolve_source_to_stream()`  instead")
#     149 def resolve_file_source(
#     150     source: Union[Path, AnyHttpUrl, str],
#     151     headers: Optional[Dict[str, str]] = None,
#     152 ) -> Path:
#     153     """Resolves the source (URL, path) of a file to a local file path.
#     154
#     155     If a URL is provided, the content is first downloaded to a temporary local file.
#    (...)
#     166         Path: The local file path.
#     167     """
# --> 168     return _resolve_source_to_path(
#     169         source=source,
#     170         headers=headers,
#     171     )
#
# File f:\MERI-main-test\.venv\Lib\site-packages\docling_core\utils\file.py:101, in _resolve_source_to_path(source, headers, workdir)
#      96 def _resolve_source_to_path(
#      97     source: Union[Path, AnyHttpUrl, str],
#      98     headers: Optional[Dict[str, str]] = None,
#      99     workdir: Optional[Path] = None,
#     100 ) -> Path:
# --> 101     doc_stream = resolve_source_to_stream(source=source, headers=headers)
#     103     # use a temporary directory if not specified
#     104     if workdir is None:
#
# File f:\MERI-main-test\.venv\Lib\site-packages\docling_core\utils\file.py:89, in resolve_source_to_stream(source, headers)
#      87 try:
#      88     local_path = TypeAdapter(Path).validate_python(source)
# ---> 89     stream = BytesIO(local_path.read_bytes())
#      90     doc_stream = DocumentStream(name=local_path.name, stream=stream)
#      91 except ValidationError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pathlib.py:1020, in Path.read_bytes(self)
#    1016 def read_bytes(self):
#    1017     """
#    1018     Open the file in bytes mode, read it, and close the file.
#    1019     """
# -> 1020     with self.open(mode='rb') as f:
#    1021         return f.read()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pathlib.py:1014, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1012 if "b" not in mode:
#    1013     encoding = io.text_encoding(encoding)
# -> 1014 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'f:\\data\\demo_data\\user_test.pdf'

# %%
Markdown(meri.int_format)
