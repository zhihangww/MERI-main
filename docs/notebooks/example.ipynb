# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from PIL import Image, ImageDraw
from meri.utils.docling_utils import vis_layout
from meri.meri import MERI
import json
from IPython.display import display, Image, Markdown

base_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.append(base_path)
# Out:
# /root/.cache/pypoetry/virtualenvs/meri-mfjPNI09-py3.12/lib/python3.12/site-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)

# %%
pdf_path = f'{base_path}/data/demo_data/Alfa Laval LKH.pdf'
with open(f'{base_path}/data/demo_data/dummy_schema.json') as f:
    schema = json.load(f)

# %%
meri = MERI(pdf_path, model="gpt-4o-mini", model_temp=0.0)
#meri = MERI(pdf_path, model="azure/gpt-4o", model_temp=0.0)

# %%
meri.to_intermediate()
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
layout = meri.vis_layout()
for img in layout:
    display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=596x842>
# <PIL.Image.Image image mode=RGB size=596x842>
# <PIL.Image.Image image mode=RGB size=596x842>
# <PIL.Image.Image image mode=RGB size=596x842>

# %%
Markdown(meri.int_format)
# Out:
# <h2 className="section_wrapper" bbox="[55.65477752685547, 121.753173828125, 187.24447631835938, 139.23626708984375]" page_index="0">Alfa Laval LKH</h2>
#
# <h2 className="section_wrapper" bbox="[56.226646423339844, 156.989990234375, 159.6615447998047, 169.596923828125]" page_index="0">Centrifugal Pumps</h2>
#
# <h2 className="section_wrapper" bbox="[56.48418045043945, 216.14764404296875, 106.95443725585938, 223.9920654296875]" page_index="0">Introduction</h2>
#
# <div className="text_wrapper" bbox="[55.85820007324219, 229.15252685546875, 297.181884765625, 286.9129638671875]" page_index="0">The Alfa Laval LKH Centrifugal Pump is a premium pump for use in hygienic applications. To increase process productivity, it is distinguished by high efficiency, gentle product treatment, chemical resistance, and a wide range of flow rates, pressures and options.</div>
#
# ...

# %%
parameters_pred = meri.run(json.dumps(schema))
# Out:
# computing with character threshold:  450000
# Number of chunks: 1
# Number of content chunks: 1
# Round:  0
# Processing content chunks: 100%|██████████| 1/1 [00:23<00:00, 23.84s/it]

# %%
parameters_pred
# Out:
# {'title': {'text': 'Alfa Laval LKH',
#   'bbox': [55.65477752685547,
#    121.753173828125,
#    187.24447631835938,
#    139.23626708984375],
#   'pageIndex': 0},
#  'technicalSpecifications': {'INSIDE_SURFACE_FINISH': {'parameter_properties': {'value': 0,
#     'text': 'Standard blasted',
#     'unit': None,
#     'bbox': [57.23193359375,
#      114.01763916015625,
#      116.80892181396484,
#      119.1136474609375],
#     'pageIndex': 1}},
#   'INLET_WATER_PRESSURE': {'parameter_properties': {'value': 1,
#     'text': 'Max. 1 bar',
#     'unit': 'bar',
#     'bbox': [56.69293212890625,
#      518.8226928710938,
#      337.1414489746094,
#      523.9186706542969],
#     'pageIndex': 1}},
#   'TEMPERATURE_RANGE': {'parameter_properties': {'value': -10,
#     'text': '-10°C to +140°C',
#     'unit': '°C',
#     'bbox': [56.66493225097656,
#      460.0648193359375,
#      114.63893127441406,
#      466.497802734375],
#     'pageIndex': 1}},
# ...
